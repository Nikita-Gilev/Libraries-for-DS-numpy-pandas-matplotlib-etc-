# %% [markdown]
# ## Задание 1

# %%
# Библиотеки, которые используюся в работе
import pandas as pd
import numpy as np
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_auc_score
from sklearn.datasets import load_wine

# %%
boston = load_boston()
boston['data'].shape
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function load_boston is deprecated; `load_boston` is deprecated in 1.0 and will be removed in 1.2.
#
#     The Boston housing prices dataset has an ethical problem. You can refer to
#     the documentation of this function for further details.
#
#     The scikit-learn maintainers therefore strongly discourage the use of this
#     dataset unless the purpose of the code is to study and educate about
#     ethical issues in data science and machine learning.
#
#     In this special case, you can fetch the dataset from the original
#     source::
#
#         import pandas as pd
#         import numpy as np
#
#
#         data_url = "http://lib.stat.cmu.edu/datasets/boston"
#         raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#         data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
#         target = raw_df.values[1::2, 2]
#
# ...

# %%
data = boston['data']
feature_names = boston['feature_names']
target = boston['target']

# %%
X = pd.DataFrame(data, columns=feature_names)
y = pd.DataFrame(target,columns=['price'])

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 13 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    float64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
# dtypes: float64(13)
# memory usage: 51.5 KB

# %%
y.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   price   506 non-null    float64
# dtypes: float64(1)
# memory usage: 4.1 KB

# %%
? train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3,random_state=42)

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

y_pred.shape
# Out:
# (152, 1)

# %%
check_test = pd.DataFrame({
    "y_test": y_test["price"],
    "y_pred": y_pred.flatten(),
})

check_test.head(10)
# Out:
#      y_test     y_pred
# 173    23.6  28.648960
# 274    32.4  36.495014
# 491    13.6  15.411193
# 72     22.8  25.403213
# 452    16.1  18.855280
# 76     20.0  23.146689
# 316    17.8  17.392124
# 140    14.0  14.078599
# 471    19.6  23.036927
# 500    16.8  20.599433

# %%
r2_score(y_test, y_pred)
# Out:
# 0.7112260057484974

# %% [markdown]
# ## Задание 2

# %%
model = RandomForestRegressor(n_estimators=1000, max_depth=12, random_state=42)

# %%
model.fit(X_train, y_train.values[:,0])
# Out:
# RandomForestRegressor(max_depth=12, n_estimators=1000, random_state=42)

# %%
y_pred2 = model.predict(X_test)

# %%
check_test2 = pd.DataFrame({
    "y_test": y_test["price"],
    "y_pred2": y_pred2.flatten(),
    "error": y_pred2.flatten() - y_test["price"]
})
check_test2.head(10)
# Out:
#      y_test    y_pred2     error
# 173    23.6  22.806412 -0.793588
# 274    32.4  31.131464 -1.268536
# 491    13.6  16.339125  2.739125
# 72     22.8  23.810726  1.010726
# 452    16.1  17.139521  1.039521
# 76     20.0  21.832284  1.832284
# 316    17.8  19.895747  2.095747
# 140    14.0  14.754118  0.754118
# 471    19.6  21.240835  1.640835
# 500    16.8  20.898658  4.098658

# %%
# коэффициент детерминации в данном задании , показал лучше соответствие модели (0.87499 против 0.71122)

r2_score(y_test, y_pred2)
# Out:
# 0.87472606157312

# %% [markdown]
# ## * Задание 3

# %%
? RandomForestRegressor

# %%
# ?model.feature_importances_

# %%
model.feature_importances_
# Out:
# array([0.03167574, 0.00154252, 0.00713813, 0.00123624, 0.01426897,
#        0.40268179, 0.01429864, 0.06397257, 0.00528122, 0.01152493,
#        0.01808108, 0.01245085, 0.41584732])

# %%
feature_importance = model.feature_importances_

# %%
# Сумма всех показателей важности

sum_features = np.sum(feature_importance)
print(sum_features)
# Out:
# 1.0

# %%
idx = np.argsort(feature_importance)
sorted_idx = np.flipud(idx)
print(f"idx:\n {idx}\n")
print(f"sorted_idx:\n {sorted_idx}")
# Out:
# idx:
#  [ 3  1  8  2  9 11  4  6 10  0  7  5 12]
#
# sorted_idx:
#  [12  5  7  0 10  6  4 11  9  2  8  1  3]

# %%
feature_importance[sorted_idx]
# Out:
# array([0.41584732, 0.40268179, 0.06397257, 0.03167574, 0.01808108,
#        0.01429864, 0.01426897, 0.01245085, 0.01152493, 0.00713813,
#        0.00528122, 0.00154252, 0.00123624])

# %%
X.columns[sorted_idx]
# Out:
# Index(['LSTAT', 'RM', 'DIS', 'CRIM', 'PTRATIO', 'AGE', 'NOX', 'B', 'TAX',
#        'INDUS', 'RAD', 'ZN', 'CHAS'],
#       dtype='object')

# %%
check_test3 = pd.DataFrame({
    "Признак": X.columns[sorted_idx],
    "Значимость": feature_importance[sorted_idx]
})
check_test3.head() # Наибольшую важность показали признаки LSTAT (0.415679) и RM (0.402705)
# Out:
#    Признак  Значимость
# 0    LSTAT    0.415847
# 1       RM    0.402682
# 2      DIS    0.063973
# 3     CRIM    0.031676
# 4  PTRATIO    0.018081

# %% [markdown]
# ## * Задание 4

# %%
import pandas as pd
import io

# %%
df = pd.read_csv('/content/sample_data/creditcard.csv', sep=',')
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.918649e-15  5.682686e-16 -8.761736e-15  2.811118e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552103e-15  2.040130e-15 -1.698953e-15 -1.893285e-16 -3.147640e-15
# ...

# %%
df['Class'].value_counts(normalize=True)
# Out:
# 0    0.998273
# 1    0.001727
# Name: Class, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
pd.options.display.max_columns = 100

# %%
#первые 10 строк датасета
df.head(10)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5   2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6   4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
# 7   7.0 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 8   7.0 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
# 9   9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
#
#          V8        V9       V10       V11       V12       V13       V14  \
# ...

# %%
#выделим из выборки столбец Class запишем в переменные x и y 
X  = df.iloc[:,0:30]
y = pd.Series(df['Class'])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=100, stratify=y)

# %%
print(f"X shape: {X.shape}")
print(f"y shape: {y.shape}\n")
print(f"X_train shape: {X_train.shape}")
print(f"X_test shape: {X_test.shape}\n")
print(f"y_train shape: {y_train.shape}")
print(f"y_test shape: {y_test.shape}")
# Out:
# X shape: (284807, 30)
# y shape: (284807,)
#
# X_train shape: (199364, 30)
# X_test shape: (85443, 30)
#
# y_train shape: (199364,)
# y_test shape: (85443,)

# %%
# ?train_test_split

# %% [markdown]
# Создаем модель `GridSearchCV`с указанными параметрами

# %%
parameters = [{'n_estimators': [10, 15], 'max_features': np.arange(3, 5), 'max_depth': np.arange(4, 7)}]
model_2 = GridSearchCV(
    estimator=RandomForestClassifier(random_state=100),
    param_grid=parameters,
    scoring='roc_auc',
    cv=3,
)

# %% [markdown]
# Обучаем модель на тренировочном наборе данных

# %%
model_2.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=3, estimator=RandomForestClassifier(random_state=100),
#              param_grid=[{'max_depth': array([4, 5, 6]),
#                           'max_features': array([3, 4]),
#                           'n_estimators': [10, 15]}],
#              scoring='roc_auc')

# %%
model_2.best_params_
# Out:
# {'max_depth': 6, 'max_features': 3, 'n_estimators': 15}

# %%
X_test_pred_proba = model_2.predict_proba(X_test)
X_test_pred_proba
# Out:
# array([[9.99070828e-01, 9.29171738e-04],
#        [9.99704794e-01, 2.95206364e-04],
#        [9.99717846e-01, 2.82154033e-04],
#        ...,
#        [9.99717846e-01, 2.82154033e-04],
#        [9.99317795e-01, 6.82204754e-04],
#        [9.87539019e-01, 1.24609813e-02]])

# %%
#выберем столбец класса 1 из полученного результата 
y_pred_proba = X_test_pred_proba[:,1]
y_pred_proba
# Out:
# array([0.00092917, 0.00029521, 0.00028215, ..., 0.00028215, 0.0006822 ,
#        0.01246098])

# %%
roc_auc_score(y_test, y_pred_proba)
# Out:
# 0.9462664156037156

# %% [markdown]
# ## *Дополнительные задания:

# %%
# ?load_wine
data = load_wine()
type(data)
# Out:
# sklearn.utils.Bunch

# %%
type(data['data'])
# Out:
# numpy.ndarray

# %%
data_keys = data['feature_names']
data_keys
# Out:
# ['alcohol',
#  'malic_acid',
#  'ash',
#  'alcalinity_of_ash',
#  'magnesium',
#  'total_phenols',
#  'flavanoids',
#  'nonflavanoid_phenols',
#  'proanthocyanins',
#  'color_intensity',
#  'hue',
#  'od280/od315_of_diluted_wines',
#  'proline']

# %%
#создаем датафрейм, выводим данные 
X = pd.DataFrame(data['data'], columns=data_keys)
X.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline
# ...

# %%
# описание в форматированном виде
print(data['DESCR'])
# Out:
# .. _wine_dataset:
#
# Wine recognition dataset
# ------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 178 (50 in each of three classes)
#     :Number of Attributes: 13 numeric, predictive attributes and the class
#     :Attribute Information:
#  		- Alcohol
#  		- Malic acid
#  		- Ash
# 		- Alcalinity of ash
#  		- Magnesium
# 		- Total phenols
#  		- Flavanoids
#  		- Nonflavanoid phenols
#  		- Proanthocyanins
# 		- Color intensity
#  		- Hue
#  		- OD280/OD315 of diluted wines
#  		- Proline
#
#     - class:
#             - class_0
#             - class_1
#             - class_2
#
#     :Summary Statistics:
#
#     ============================= ==== ===== ======= =====
#                                    Min   Max   Mean     SD
#     ============================= ==== ===== ======= =====
#     Alcohol:                      11.0  14.8    13.0   0.8
#     Malic Acid:                   0.74  5.80    2.34  1.12
# ...

# %%
list(data.target_names)
# Out:
# ['class_0', 'class_1', 'class_2']

# %%
X.shape
# Out:
# (178, 13)

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   alcohol                       178 non-null    float64
#  1   malic_acid                    178 non-null    float64
#  2   ash                           178 non-null    float64
#  3   alcalinity_of_ash             178 non-null    float64
#  4   magnesium                     178 non-null    float64
#  5   total_phenols                 178 non-null    float64
#  6   flavanoids                    178 non-null    float64
#  7   nonflavanoid_phenols          178 non-null    float64
#  8   proanthocyanins               178 non-null    float64
#  9   color_intensity               178 non-null    float64
#  10  hue                           178 non-null    float64
#  11  od280/od315_of_diluted_wines  178 non-null    float64
# ...

# %% [markdown]
# Добвим в датафрейм поле `target` с классами вин

# %%
X['target'] = data['target'].astype('int64')
# X.info()
X.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline  target
# ...

# %%
#Построим матрицу корреляций `X_corr` 
X_corr = X.corr()
X_corr
# Out:
#                                alcohol  malic_acid       ash  \
# alcohol                       1.000000    0.094397  0.211545
# malic_acid                    0.094397    1.000000  0.164045
# ash                           0.211545    0.164045  1.000000
# alcalinity_of_ash            -0.310235    0.288500  0.443367
# alcalinity_of_ash_2          -0.292040    0.270947  0.454174
# magnesium                     0.270798   -0.054575  0.286587
# total_phenols                 0.289101   -0.335167  0.128980
# flavanoids                    0.236815   -0.411007  0.115077
# nonflavanoid_phenols         -0.155929    0.292977  0.186230
# proanthocyanins               0.136698   -0.220746  0.009652
# color_intensity               0.546364    0.248985  0.258887
# hue                          -0.071747   -0.561296 -0.074667
# od280/od315_of_diluted_wines  0.072343   -0.368710  0.003911
# proline                       0.643720   -0.192011  0.223626
#
# ...

# %%
# high_corr =
X_corr.loc[X_corr['target']>abs(0.5),'target']
# Out:
# alcalinity_of_ash    0.517859
# target               1.000000
# Name: target, dtype: float64

# %%
X_corr.index
# Out:
# Index(['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium',
#        'total_phenols', 'flavanoids', 'nonflavanoid_phenols',
#        'proanthocyanins', 'color_intensity', 'hue',
#        'od280/od315_of_diluted_wines', 'proline', 'target'],
#       dtype='object')

# %%
high_corr = X_corr.iloc[0:13,0:0].loc[X_corr['target']>abs(0.5)].index.tolist()
high_corr
# Out:
# ['alcalinity_of_ash']

# %%
X.drop(['target'], axis='columns', inplace=True)

# %%
X['alcalinity_of_ash' + '_2']=X['alcalinity_of_ash']**2
X.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline  alcalinity_of_ash_2
# ...

# %%
list(X.columns.values)
X = X[['alcohol',
 'malic_acid',
 'ash',
 'alcalinity_of_ash',
 'alcalinity_of_ash_2',
 'magnesium',
 'total_phenols',
 'flavanoids',
 'nonflavanoid_phenols',
 'proanthocyanins',
 'color_intensity',
 'hue',
 'od280/od315_of_diluted_wines',
 'proline']]

# %%
#выводим полученные данные
X.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  alcalinity_of_ash_2  \
# 0    14.23        1.71  2.43               15.6               243.36
# 1    13.20        1.78  2.14               11.2               125.44
# 2    13.16        2.36  2.67               18.6               345.96
# 3    14.37        1.95  2.50               16.8               282.24
# 4    13.24        2.59  2.87               21.0               441.00
#
#    magnesium  total_phenols  flavanoids  nonflavanoid_phenols  \
# 0      127.0           2.80        3.06                  0.28
# 1      100.0           2.65        2.76                  0.26
# 2      101.0           2.80        3.24                  0.30
# 3      113.0           3.85        3.49                  0.24
# 4      118.0           2.80        2.69                  0.39
#
#    proanthocyanins  color_intensity   hue  od280/od315_of_diluted_wines  \
# 0             2.29             5.64  1.04                          3.92
# ...

# %%
X.describe()
# Out:
#           alcohol  malic_acid         ash  alcalinity_of_ash  \
# count  178.000000  178.000000  178.000000         178.000000
# mean    13.000618    2.336348    2.366517          19.494944
# std      0.811827    1.117146    0.274344           3.339564
# min     11.030000    0.740000    1.360000          10.600000
# 25%     12.362500    1.602500    2.210000          17.200000
# 50%     13.050000    1.865000    2.360000          19.500000
# 75%     13.677500    3.082500    2.557500          21.500000
# max     14.830000    5.800000    3.230000          30.000000
#
#        alcalinity_of_ash_2   magnesium  total_phenols  flavanoids  \
# count           178.000000  178.000000     178.000000  178.000000
# mean            391.142865   99.741573       2.295112    2.029270
# std             133.671775   14.282484       0.625851    0.998859
# min             112.360000   70.000000       0.980000    0.340000
# 25%             295.840000   88.000000       1.742500    1.205000
# ...
